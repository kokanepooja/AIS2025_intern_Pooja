# %% [markdown]
# # Section 1 :if,if else,if-elif-else

# %%
# Python program for the number is popsitive
num = int(input("Entre the Number: "))
if num > 0:
    print("The number is positive.")
# Out:
# Enter a number:  5
# The number is positive.

# %%
#Python program to check wheather a person is eligible to vote
age = int(input("Enter your age: "))
if age >= 18:
    print("You are eligible to vote.")
else:
    print("You are not eligible to vote.")
# Out:
# Enter your age:  14
# You are not eligible to vote.

# %%
#Python program for a number is positive,negative,or zero using if-elif-else
num = float(input("Enter a number: "))
if num > 0:
    print("Positive number")
elif num < 0:
    print("Negative number")
else:
    print("Zero")
# Out:
# Enter a number:  -8
# Negative number

# %%
#Python program for input marks for pass or fail
marks = int(input("Enter your marks: "))
if marks >= 35:
    print("Pass")
else:
    print("Fail")
# Out:
# Enter your marks:  52
# Pass

# %%
#Python program for that takes number and checks
num = int(input("Enter a number: "))
if num % 3 == 0:
    print("Divisible by 3")
elif num % 5 == 0:
    print("Divisible by 5")
else:
    print("Not divisible by 3 or 5")
# Out:
# Enter a number:  7
# Not divisible by 3 or 5

# %%
#Python program for if
age=int(input("Enter your age:"))
if age >= 18:
        print("Eligible for voting")
        print("out of if")
# Out:
# Enter your age: 25
# Eligible for voting
# out of if

# %%
# if statement
age=int(input("Entre your name"))
if age >=18:
 print("Eiligibal")
# Out:
# Entre your name 3

# %%
# if statement
x=10;y=20
if x:
    print("true")
    print("out of if")
# Out:
# true
# out of if

# %%
# if else statement
x=int(input("Entre value for x:"))
if x>20:
    print("if x is greater")
else:
    print("if x is smaller")
# Out:
# Entre value for x: 23
# if x is greater

# %%
# if else statement
num=int(input("Entre the number"))
if num % 2==0:
    print("%d is even"%num)
else:
    print("%d is odd"%num)
# Out:
# Entre the number 16
# 16 is even

# %%
# if elif else statement
num=int(input("Entre the number"))
if num >0:
        print("{} is positive".format(num))
elif num<0:
        print("{} is negative".format(num))
else:
        print("num is zero")
# Out:
# Entre the number -52
# -52 is negative
