# %%
# Numbers

# %%
# Introducation to number (int float,complex)
Numbers are fundamental data type in python used to store numeric values.Python supports three main Numeric type:
'int':Integer values(whole numbers)
'float':Floating-Point numbers(Decimal)
'complex':Complex numbers(real+imaginary part)

Their valu cannot change once Assigned.
# key Point
-nujmber can be used in mathamatical expressions.
-Python handles integers of any size.
-floats are represented with a decimal points.
-complex numbers are written as'a+bj.
-common arithamatic operators:'+','-','*','/','//','%','**'
# Out:
#   Cell In[27], line 12
#     -complex numbers are written as'a+bj.
#                                    ^
# SyntaxError: unterminated string literal (detected at line 12)

# %%
age=20

# %%
print(age)
# Out:
# 20

# %%
print(type(age))
# Out:
# <class 'int'>

# %% [markdown]
# # float

# %%
price=75.50

# %%
print(price)
# Out:
# 75.5

# %%
print(type(price))
# Out:
# <class 'float'>

# %% [markdown]
# # complex

# %%
complexnumber=5+3j
print(complexnumber)
print(type(complexnumber))
# Out:
# (5+3j)
# <class 'complex'>
