# %% [markdown]
# # Variable declaration

# %%
Name="Pooja"

# %%
Name
# Out:
# 'Pooja'

# %%
age=23

# %%
is_student=True

# %%
is_student
# Out:
# True

# %% [markdown]
# # Arithamatic Opration

# %%
a=20

# %%
b=10

# %%
print("Addition:",a+b)
# Out:
# Addition: 30

# %%
print("Subtraction:",a-b)
# Out:
# Subtraction: 10

# %%
print("Multiplication:",a*b)
# Out:
# Multiplication: 200

# %%
print("Division:",a/b)
# Out:
# Division: 2.0

# %%
print("Modulus:",a%b)
# Out:
# Modulus: 0

# %%
print("Exponentiation:",a**b)
# Out:
# Exponentiation: 10240000000000

# %% [markdown]
# # Comparison Operator

# %%
a=10;b=20

# %%
print("a==b",a==b)
# Out:
# a==b False

# %%
print("a!=b",a!=b)
# Out:
# a!=b True

# %%
print("a>=b",a>=b)
# Out:
# a>=b False

# %%
print("a<=b",a<=b)
# Out:
# a<=b True

# %%
print("a>b",a>b)
# Out:
# a>b False

# %%
print("a<b",a<b)
# Out:
# a<b True

# %% [markdown]
# # Logical Operator

# %%
a=10;b=20

# %%
print(a>0 or b>0)
# Out:
# True

# %%
print(a<0 or b<0)
# Out:
# False

# %%
print(not (a>b))
# Out:
# True

# %%
print(not (b>a))
# Out:
# False

# %% [markdown]
# # Assignment Operator

# %%
a=5;b=3

# %%
a+=2

# %%
a
# Out:
# 7

# %%
a-=3

# %%
b
# Out:
# 3

# %%
a*=2

# %%
a
# Out:
# 8

# %%
b/=2

# %%
b
# Out:
# 1.5

# %%
a//=2

# %%
b
# Out:
# 1.5

# %%
b//=3

# %%
a
# Out:
# 4

# %%
b%=2

# %%
b
# Out:
# 0.0

# %%
a**=2

# %%
a
# Out:
# 16

# %% [markdown]
# # Membership Operators

# %%
name=["neha","samiksha","pooja","kajal"]

# %%
print("sam" in name)
# Out:
# False

# %%
print("kajal" not in name)
# Out:
# False
